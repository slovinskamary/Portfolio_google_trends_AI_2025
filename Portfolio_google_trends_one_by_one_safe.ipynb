# %% [markdown]
# # 📈 Google Trends — One by one safe
# This notebook allows querying data by a single keyword and storing results only when available.

# %% [markdown]
# ## 📦 Install lib

# %%
# !pip install pytrends

# %% [markdown]
# ## 🔧 Import and Connect Google Trends

# %%
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt
import time

pytrends = TrendReq(hl='en-US', tz=360)

# %% [markdown]
# ## 🧠 Step 1: Add the first keyword

# %%
keyword = "Langchain"  # ← Change to the next keyword
pytrends.build_payload([keyword], timeframe='today 12-m')

# %% [markdown]
# ## 📊 Step 2: Retrieve the time trend and save it if data is available

# %%
df = pytrends.interest_over_time()

if not df.empty and keyword in df.columns:
    df = df[[keyword]]
    filename = f"trend_{keyword.replace(' ', '_')}.csv"
    df.to_csv(filename)
    print(f"✅ Дані знайдено та збережено як {filename}")
    display(df.head())
else:
    print(f"⚠️ Немає даних для ключового слова: '{keyword}'. Спробуй інше.")
# Out:
# ✅ Дані знайдено та збережено як trend_Langchain.csv
# /opt/anaconda3/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#             Langchain
# date
# 2024-04-07         99
# 2024-04-14         96
# 2024-04-21         98
# 2024-04-28         88
# 2024-05-05         96

# %% [markdown]
# ## 📈 Step 3: Create plot if data is available

# %%
if not df.empty and keyword in df.columns:
    df.plot(figsize=(12,5), title=f"Google Trends: {keyword}")
    plt.ylabel("Interest over time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("❌ Графік не збудовано — немає даних.")

# %% [markdown]
# ## 🔁 Repeat this process for each keyword, changing the `keyword`.

# %% [markdown]
# - "Claude"
# - "Bolt.new"
# - "v0.dev"
# - "Replit"
# - "Lovable"
# - "GitHub Copilot"
# - "Windsurf AI"
# - "JetBrains AI Assistant"
# - "Qodo plugin"
# - "Langchain"
# - "OpenAI"
# - "ChatGPT"
# - "LLM"
# - "AI assistant"
# - "AI plugin"

# %%
keyword_1 = "Bolt.new"  
pytrends.build_payload([keyword_1], timeframe='today 12-m')

# %%
df = pytrends.interest_over_time()

if not df.empty and keyword_1 in df.columns:
    df = df[[keyword_1]]
    filename = f"trend_{keyword_1.replace(' ', '_')}.csv"
    df.to_csv(filename)
    print(f"✅ Дані знайдено та збережено як {filename}")
    display(df.head())
else:
    print(f"⚠️ Немає даних для ключового слова: '{keyword_1}'. Спробуй інше.")
# Out:
# ✅ Дані знайдено та збережено як trend_Bolt.new.csv
# /opt/anaconda3/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#             Bolt.new
# date
# 2024-04-07         0
# 2024-04-14         0
# 2024-04-21         0
# 2024-04-28         0
# 2024-05-05         0

# %%
if not df.empty and keyword_1 in df.columns:
    df.plot(figsize=(12,5), title=f"Google Trends: {keyword_1}")
    plt.ylabel("Interest over time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("❌ Графік не збудовано — немає даних.")

# %%
keyword_2 = "v0.dev" 
pytrends.build_payload([keyword_2], timeframe='today 12-m')

# %%
df = pytrends.interest_over_time()

if not df.empty and keyword_2 in df.columns:
    df = df[[keyword_2]]
    filename = f"trend_{keyword_2.replace(' ', '_')}.csv"
    df.to_csv(filename)
    print(f"✅ Дані знайдено та збережено як {filename}")
    display(df.head())
else:
    print(f"⚠️ Немає даних для ключового слова: '{keyword_2}'. Спробуй інше.")
# Out:
# ✅ Дані знайдено та збережено як trend_v0.dev.csv
# /opt/anaconda3/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#             v0.dev
# date
# 2024-04-07       0
# 2024-04-14       0
# 2024-04-21      13
# 2024-04-28       0
# 2024-05-05       0

# %%
if not df.empty and keyword_2 in df.columns:
    df.plot(figsize=(12,5), title=f"Google Trends: {keyword_2}")
    plt.ylabel("Interest over time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("❌ Графік не збудовано — немає даних.")

# %%
keyword_3 = "Replit"  
pytrends.build_payload([keyword_3], timeframe='today 12-m')

# %%
df = pytrends.interest_over_time()

if not df.empty and keyword_3 in df.columns:
    df = df[[keyword_3]]
    filename = f"trend_{keyword_3.replace(' ', '_')}.csv"
    df.to_csv(filename)
    print(f"✅ Дані знайдено та збережено як {filename}")
    display(df.head())
else:
    print(f"⚠️ Немає даних для ключового слова: '{keyword_3}'. Спробуй інше.")
# Out:
# ✅ Дані знайдено та збережено як trend_Replit.csv
# /opt/anaconda3/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#             Replit
# date
# 2024-04-07      72
# 2024-04-14      79
# 2024-04-21      74
# 2024-04-28      75
# 2024-05-05      71

# %%
if not df.empty and keyword_3 in df.columns:
    df.plot(figsize=(12,5), title=f"Google Trends: {keyword_3}")
    plt.ylabel("Interest over time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("❌ Графік не збудовано — немає даних.")

# %%
keyword_3 = "Lovable"  
pytrends.build_payload([keyword_3], timeframe='today 12-m')

# %%
df = pytrends.interest_over_time()

if not df.empty and keyword_3 in df.columns:
    df = df[[keyword_3]]
    filename = f"trend_{keyword_3.replace(' ', '_')}.csv"
    df.to_csv(filename)
    print(f"✅ Дані знайдено та збережено як {filename}")
    display(df.head())
else:
    print(f"⚠️ Немає даних для ключового слова: '{keyword_3}'. Спробуй інше.")
# Out:
# ✅ Дані знайдено та збережено як trend_Lovable.csv
# /opt/anaconda3/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#             Lovable
# date
# 2024-04-07       14
# 2024-04-14       15
# 2024-04-21       16
# 2024-04-28       16
# 2024-05-05       16

# %%
if not df.empty and keyword_3 in df.columns:
    df.plot(figsize=(12,5), title=f"Google Trends: {keyword_3}")
    plt.ylabel("Interest over time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("❌ Графік не збудовано — немає даних.")

# %%
keyword_3 = "GitHub Copilot"  
pytrends.build_payload([keyword_3], timeframe='today 12-m')

# %%
df = pytrends.interest_over_time()

if not df.empty and keyword_3 in df.columns:
    df = df[[keyword_3]]
    filename = f"trend_{keyword_3.replace(' ', '_')}.csv"
    df.to_csv(filename)
    print(f"✅ Дані знайдено та збережено як {filename}")
    display(df.head())
else:
    print(f"⚠️ Немає даних для ключового слова: '{keyword_3}'. Спробуй інше.")
# Out:
# ✅ Дані знайдено та збережено як trend_GitHub_Copilot.csv
# /opt/anaconda3/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#             GitHub Copilot
# date
# 2024-04-07              53
# 2024-04-14              49
# 2024-04-21              46
# 2024-04-28              50
# 2024-05-05              50

# %%
if not df.empty and keyword_3 in df.columns:
    df.plot(figsize=(12,5), title=f"Google Trends: {keyword_3}")
    plt.ylabel("Interest over time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("❌ Графік не збудовано — немає даних.")

# %%
keyword_3 = "Windsurf AI"  
pytrends.build_payload([keyword_3], timeframe='today 12-m')

# %%
df = pytrends.interest_over_time()

if not df.empty and keyword_3 in df.columns:
    df = df[[keyword_3]]
    filename = f"trend_{keyword_3.replace(' ', '_')}.csv"
    df.to_csv(filename)
    print(f"✅ Дані знайдено та збережено як {filename}")
    display(df.head())
else:
    print(f"⚠️ Немає даних для ключового слова: '{keyword_3}'. Спробуй інше.")
# Out:
# ✅ Дані знайдено та збережено як trend_Windsurf_AI.csv
# /opt/anaconda3/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#             Windsurf AI
# date
# 2024-04-07            0
# 2024-04-14            0
# 2024-04-21            0
# 2024-04-28            0
# 2024-05-05            0

# %%
if not df.empty and keyword_3 in df.columns:
    df.plot(figsize=(12,5), title=f"Google Trends: {keyword_3}")
    plt.ylabel("Interest over time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("❌ Графік не збудовано — немає даних.")

# %%
keyword_3 = "JetBrains AI Assistant"  
pytrends.build_payload([keyword_3], timeframe='today 12-m')

# %%
df = pytrends.interest_over_time()

if not df.empty and keyword_3 in df.columns:
    df = df[[keyword_3]]
    filename = f"trend_{keyword_3.replace(' ', '_')}.csv"
    df.to_csv(filename)
    print(f"✅ Дані знайдено та збережено як {filename}")
    display(df.head())
else:
    print(f"⚠️ Немає даних для ключового слова: '{keyword_3}'. Спробуй інше.")
# Out:
# ✅ Дані знайдено та збережено як trend_JetBrains_AI_Assistant.csv
# /opt/anaconda3/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#             JetBrains AI Assistant
# date
# 2024-04-07                      68
# 2024-04-14                      64
# 2024-04-21                      49
# 2024-04-28                      51
# 2024-05-05                      52

# %%
if not df.empty and keyword_3 in df.columns:
    df.plot(figsize=(12,5), title=f"Google Trends: {keyword_3}")
    plt.ylabel("Interest over time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("❌ Графік не збудовано — немає даних.")

# %%
keyword_3 = "Qodo plugin"  
pytrends.build_payload([keyword_3], timeframe='today 12-m')

# %%
df = pytrends.interest_over_time()

if not df.empty and keyword_3 in df.columns:
    df = df[[keyword_3]]
    filename = f"trend_{keyword_3.replace(' ', '_')}.csv"
    df.to_csv(filename)
    print(f"✅ Дані знайдено та збережено як {filename}")
    display(df.head())
else:
    print(f"⚠️ Немає даних для ключового слова: '{keyword_3}'. Спробуй інше.")
# Out:
# ✅ Дані знайдено та збережено як trend_Qodo_plugin.csv
# /opt/anaconda3/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#             Qodo plugin
# date
# 2024-04-07            0
# 2024-04-14            0
# 2024-04-21            0
# 2024-04-28            0
# 2024-05-05            0

# %%
if not df.empty and keyword_3 in df.columns:
    df.plot(figsize=(12,5), title=f"Google Trends: {keyword_3}")
    plt.ylabel("Interest over time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("❌ Графік не збудовано — немає даних.")

# %%
keyword_3 = "OpenAI"  
pytrends.build_payload([keyword_3], timeframe='today 12-m')

# %%
df = pytrends.interest_over_time()

if not df.empty and keyword_3 in df.columns:
    df = df[[keyword_3]]
    filename = f"trend_{keyword_3.replace(' ', '_')}.csv"
    df.to_csv(filename)
    print(f"✅ Дані знайдено та збережено як {filename}")
    display(df.head())
else:
    print(f"⚠️ Немає даних для ключового слова: '{keyword_3}'. Спробуй інше.")
# Out:
# ✅ Дані знайдено та збережено як trend_OpenAI.csv
# /opt/anaconda3/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#             OpenAI
# date
# 2024-04-07      51
# 2024-04-14      51
# 2024-04-21      50
# 2024-04-28      47
# 2024-05-05      50

# %%
if not df.empty and keyword_3 in df.columns:
    df.plot(figsize=(12,5), title=f"Google Trends: {keyword_3}")
    plt.ylabel("Interest over time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("❌ Графік не збудовано — немає даних.")

# %%
keyword_3 = "ChatGPT"  
pytrends.build_payload([keyword_3], timeframe='today 12-m')

# %%
df = pytrends.interest_over_time()

if not df.empty and keyword_3 in df.columns:
    df = df[[keyword_3]]
    filename = f"trend_{keyword_3.replace(' ', '_')}.csv"
    df.to_csv(filename)
    print(f"✅ Дані знайдено та збережено як {filename}")
    display(df.head())
else:
    print(f"⚠️ Немає даних для ключового слова: '{keyword_3}'. Спробуй інше.")
# Out:
# ✅ Дані знайдено та збережено як trend_ChatGPT.csv
# /opt/anaconda3/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#             ChatGPT
# date
# 2024-04-07       25
# 2024-04-14       27
# 2024-04-21       27
# 2024-04-28       28
# 2024-05-05       26

# %%
if not df.empty and keyword_3 in df.columns:
    df.plot(figsize=(12,5), title=f"Google Trends: {keyword_3}")
    plt.ylabel("Interest over time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("❌ Графік не збудовано — немає даних.")

# %%
keyword_3 = "LLM"  
pytrends.build_payload([keyword_3], timeframe='today 12-m')

# %%
df = pytrends.interest_over_time()

if not df.empty and keyword_3 in df.columns:
    df = df[[keyword_3]]
    filename = f"trend_{keyword_3.replace(' ', '_')}.csv"
    df.to_csv(filename)
    print(f"✅ Дані знайдено та збережено як {filename}")
    display(df.head())
else:
    print(f"⚠️ Немає даних для ключового слова: '{keyword_3}'. Спробуй інше.")
# Out:
# ✅ Дані знайдено та збережено як trend_LLM.csv
# /opt/anaconda3/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#             LLM
# date
# 2024-04-07   55
# 2024-04-14   55
# 2024-04-21   62
# 2024-04-28   50
# 2024-05-05   54

# %%
if not df.empty and keyword_3 in df.columns:
    df.plot(figsize=(12,5), title=f"Google Trends: {keyword_3}")
    plt.ylabel("Interest over time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("❌ Графік не збудовано — немає даних.")

# %% [markdown]
# "AI assistant",
#     "AI plugin"

# %%
keyword_3 = "AI assistant"  
pytrends.build_payload([keyword_3], timeframe='today 12-m')

# %%
df = pytrends.interest_over_time()

if not df.empty and keyword_3 in df.columns:
    df = df[[keyword_3]]
    filename = f"trend_{keyword_3.replace(' ', '_')}.csv"
    df.to_csv(filename)
    print(f"✅ Дані знайдено та збережено як {filename}")
    display(df.head())
else:
    print(f"⚠️ Немає даних для ключового слова: '{keyword_3}'. Спробуй інше.")
# Out:
# ✅ Дані знайдено та збережено як trend_AI_assistant.csv
# /opt/anaconda3/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#             AI assistant
# date
# 2024-04-07            48
# 2024-04-14            52
# 2024-04-21            51
# 2024-04-28            47
# 2024-05-05            50

# %%
if not df.empty and keyword_3 in df.columns:
    df.plot(figsize=(12,5), title=f"Google Trends: {keyword_3}")
    plt.ylabel("Interest over time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("❌ Графік не збудовано — немає даних.")

# %%
keyword_3 = "AI plugin"  
pytrends.build_payload([keyword_3], timeframe='today 12-m')

# %%
df = pytrends.interest_over_time()

if not df.empty and keyword_3 in df.columns:
    df = df[[keyword_3]]
    filename = f"trend_{keyword_3.replace(' ', '_')}.csv"
    df.to_csv(filename)
    print(f"✅ Дані знайдено та збережено як {filename}")
    display(df.head())
else:
    print(f"⚠️ Немає даних для ключового слова: '{keyword_3}'. Спробуй інше.")
# Out:
# ✅ Дані знайдено та збережено як trend_AI_plugin.csv
# /opt/anaconda3/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#             AI plugin
# date
# 2024-04-07         64
# 2024-04-14         66
# 2024-04-21         61
# 2024-04-28         66
# 2024-05-05         66

# %%
if not df.empty and keyword_3 in df.columns:
    df.plot(figsize=(12,5), title=f"Google Trends: {keyword_3}")
    plt.ylabel("Interest over time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("❌ Графік не збудовано — немає даних.")
